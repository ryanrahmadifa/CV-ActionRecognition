# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import pyautogui

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 

    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
                             )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                             )

    # Extract index finger tip coordinates
    if results.left_hand_landmarks:
        index_finger_tip = results.left_hand_landmarks.landmark[mp_holistic.HandLandmark.INDEX_FINGER_TIP]
        index_finger_tip_x = int(index_finger_tip.x * image.shape[1])
        index_finger_tip_y = int(index_finger_tip.y * image.shape[0])
        index_finger_tip_pos = np.array((index_finger_tip_x, index_finger_tip_y))
        
        thumb_finger_tip = results.left_hand_landmarks.landmark[mp_holistic.HandLandmark.THUMB_TIP]
        thumb_finger_tip_x = int(thumb_finger_tip.x * image.shape[1])
        thumb_finger_tip_y = int(thumb_finger_tip.y * image.shape[0])
        thumb_finger_tip_pos = np.array((thumb_finger_tip_x, thumb_finger_tip_y))

        middle_finger_tip = results.left_hand_landmarks.landmark[mp_holistic.HandLandmark.MIDDLE_FINGER_TIP]
        middle_finger_tip_x = int(middle_finger_tip.x * image.shape[1])
        middle_finger_tip_y = int(middle_finger_tip.y * image.shape[0])
        middle_finger_tip_pos = np.array((middle_finger_tip_x, middle_finger_tip_y))
        
        ring_finger_dip = results.left_hand_landmarks.landmark[mp_holistic.HandLandmark.RING_FINGER_DIP]
        ring_finger_dip_x = int(ring_finger_dip.x * image.shape[1])
        ring_finger_dip_y = int(ring_finger_dip.y * image.shape[0])
        ring_finger_dip_pos = np.array((ring_finger_dip_x, ring_finger_dip_y))

        # Draw circle at the index finger tip
        radius = 8
        color = (0, 255, 0)  # Green color (BGR format)
        thickness = 3  # Outline thickness
        cv2.circle(image, (index_finger_tip_x, index_finger_tip_y), radius, color, thickness)
    
        pyautogui.moveTo(index_finger_tip_x*3, index_finger_tip_y*3)
        
        # Euclidean distance
        single_click_dist = np.linalg.norm(ring_finger_dip_pos - thumb_finger_tip_pos)
        double_click_dist = np.linalg.norm(middle_finger_tip_pos - thumb_finger_tip_pos)
        
        if single_click_dist < 15:
            pyautogui.click()
        
        elif double_click_dist < 10:
            pyautogui.click()
            pyautogui.click()
    
        # ADD SCROLLING WITH LEFT HAND

# %%
# # Extract index finger tip coordinates
# if results.right_hand_landmarks:
#     index_finger_tip = results.right_hand_landmarks.landmark[mp_holistic.HandLandmark.INDEX_FINGER_TIP]
#     index_finger_tip_x = int(index_finger_tip.x * image.shape[1])
#     index_finger_tip_y = int(index_finger_tip.y * image.shape[0])
#     index_finger_tip_z = index_finger_tip.z

#     # Draw circle at the index finger tip
#     radius = 8
#     color = (0, 255, 0)  # Green color (BGR format)
#     thickness = 1  # Fill the circle
#     image = cv2.circle(image, (index_finger_tip_x, index_finger_tip_y), radius, color, thickness)

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        
        # Flip the camera
        frame = cv2.flip(frame, 1)
        
        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
# pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
# lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
# rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
33*4+21*3+21*3
# Out:
# 258

# %% [markdown]
# ---

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['none','thanks','goodbye', 'up_vol','down_vol'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass
        
# thanks
## 0
## 1
## 2
## ...
## 29
# up_vol

# down_vol

# %%
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):
                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                

                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...

# %% [markdown]
# ---

# %%
import tensorflow
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'none': 0, 'thanks': 1, 'goodbye': 2, 'up_vol': 3, 'down_vol': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 258)

# %%
X = np.array(sequences)

# %%
#One-hot encoding

y = to_categorical(labels).astype(int)

# %%
#Split train-testing with test size being 5% of total data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# ---

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, activation='relu', input_shape=(30,258)))
model.add(LSTM(256, return_sequences=True, activation='relu'))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
optim = tensorflow.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=700, callbacks=[tb_callback])
# Out:
# Epoch 1/700
# 5/5 [==============================] - 7s 348ms/step - loss: 1.5886 - categorical_accuracy: 0.1620
# Epoch 2/700
# 5/5 [==============================] - 2s 367ms/step - loss: 1.4791 - categorical_accuracy: 0.3803
# Epoch 3/700
# 5/5 [==============================] - 2s 355ms/step - loss: 1.2723 - categorical_accuracy: 0.3732
# Epoch 4/700
# 5/5 [==============================] - 2s 341ms/step - loss: 1.1304 - categorical_accuracy: 0.4930
# Epoch 5/700
# 5/5 [==============================] - 2s 323ms/step - loss: 0.9486 - categorical_accuracy: 0.6268
# Epoch 6/700
# 5/5 [==============================] - 2s 351ms/step - loss: 0.8236 - categorical_accuracy: 0.6761
# Epoch 7/700
# 5/5 [==============================] - 2s 345ms/step - loss: 0.8179 - categorical_accuracy: 0.6761
# Epoch 8/700
# 5/5 [==============================] - 2s 316ms/step - loss: 0.7022 - categorical_accuracy: 0.7394
# Epoch 9/700
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           198144
#
#  lstm_1 (LSTM)               (None, 30, 256)           394240
#
#  lstm_2 (LSTM)               (None, 30, 128)           197120
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 5)                 165
#
# ...
# Total params: 845,317
# Trainable params: 845,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---

# %%
model.save('action_v1.h5')

# %%
del model

# %%
from tensorflow.keras.models import load_model
model = load_model('action_v1.h5')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ---

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
#yhat = model.predict(X_train)

# %%
# ytrue = np.argmax(y_train, axis=1).tolist()
# yhat = np.argmax(yhat, axis=1).tolist()

# %%
#multilabel_confusion_matrix(ytrue, yhat)

# %%
#accuracy_score(ytrue, yhat)

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tensorflow.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tensorflow.config.experimental.set_memory_growth(gpu, True)

# %%
from tensorflow.keras.models import load_model
model = load_model('action_v1.h5')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities
# Actions that we try to detect
actions = np.array(['none','thanks','goodbye', 'up_vol','down_vol'])

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_styled_landmarks(image, results):
#     # Draw face connections
#     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
#                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
#                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                              ) 
    
#     # Draw pose connections
#     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
#                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                              ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
colors = [(245,117,16), (117,245,16), (16,117,245), (21, 225, 100), (20,50,60)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np

# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5
frame_count = 0
last_predicted_motion = ""

cap = cv2.VideoCapture(0)

# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
#        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        frame_count += 1
        
        cv2.putText(image, f"Last Motion: {last_predicted_motion}", (10, 50),
            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)
        
        # 3. Check if sequence is complete and perform prediction
        if frame_count == 30:
            frame_count = 0
            
            # Predict and update predictions
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(res)
            res_norm = res/np.linalg.norm(res)
            action = np.argmax(res_norm)
            print(actions[action])
            print(res[action])
            predictions.append(action)
            
#             # Update sentence
#             if np.unique(predictions[-5:])[0] == np.argmax(res):
            if res[action] > threshold:
                last_predicted_motion = actions[np.argmax(res)]
                sentence.append(actions[np.argmax(res)])
            else:
                continue
#             else:
#                 last_predicted_motion = "none"
            
                    # Display last predicted motion as label
                

                        
#             if len(sentence) > 5:
#                 sentence = sentence[-5:]

#         # Viz probabilities
#         image = prob_viz(res, actions, image, colors)
        
#             cv2.rectangle(image, (0, 0), (480, 20), (245, 117, 16), -1)
#             cv2.putText(image, ' '.join(sentence), (3, 20), 
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
        

        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 2s 2s/step
# [0.04022221 0.02427056 0.90796375 0.00179688 0.02574659]
# goodbye
# 0.90796375
# 1/1 [==============================] - 0s 75ms/step
# [4.8501411e-01 4.6061287e-03 4.9800426e-01 8.7676699e-07 1.2374626e-02]
# goodbye
# 0.49800426
# 1/1 [==============================] - 0s 67ms/step
# [1.4171209e-03 5.1423686e-04 9.9407887e-01 4.1635030e-06 3.9856150e-03]
# goodbye
# 0.9940789
# 1/1 [==============================] - 0s 64ms/step
# [9.9140584e-01 9.7964621e-05 7.6391213e-03 1.5003478e-10 8.5705012e-04]
# none
# 0.99140584
# 1/1 [==============================] - 0s 57ms/step
# [9.9795002e-01 7.8588499e-05 1.1339668e-03 1.4125605e-11 8.3737366e-04]
# none
# 0.99795
# 1/1 [==============================] - 0s 61ms/step
# [9.9937087e-01 2.9330886e-05 1.1690203e-04 5.9898299e-13 4.8300702e-04]
# none
# 0.9993709
# 1/1 [==============================] - 0s 74ms/step
# ...
